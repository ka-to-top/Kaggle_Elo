# %% [markdown]
# * [1. Introduction](#Introduction)
#     * [1.1 Data Load](#Data_Load)
# * [2. EDA](#EDA)
#     * [2.1 Train](#Train)
#     * [2.2 Merchants](#Merchants)
#     * [2.3 Historical Transactions](#Historical_Transactions)
#     * [2.4 New Merchant Transactions](#New_Merchant_Transactions)

# %% [markdown]
# <a id='Introduction'></a>

# %% [markdown]
# # 1. Introduction

# %%
# !pip install hvplot # interactive visualization을 위해 hvplot 패키지 설치
# Out:
# ...
# You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# import packages
import pandas as pd
import hvplot.pandas

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# <a id='Data_Load'></a>

# %% [markdown]
# ## 1.1 Data Load

# %%
# Data Load
PATH = '../input/' # 경로를 변수에 할당
train = pd.read_csv(PATH + 'train.csv')
merchant = pd.read_csv(PATH + 'merchants.csv')
hist = pd.read_csv(PATH + 'historical_transactions.csv')
new_merchant = pd.read_csv(PATH + 'new_merchant_transactions.csv')

# %% [markdown]
# <a id='EDA'></a>

# %% [markdown]
# # 2. EDA

# %% [markdown]
# <a id='Train'></a>

# %% [markdown]
# ## 2.1 Train

# %%
train.head()
# Out:
#   first_active_month          card_id    ...     feature_3    target
# 0            2017-06  C_ID_92a2005557    ...             1 -0.820283
# 1            2017-01  C_ID_3d0044924f    ...             0  0.392913
# 2            2016-08  C_ID_d639edf6cd    ...             0  0.688056
# 3            2017-09  C_ID_186d6a6901    ...             0  0.142495
# 4            2017-11  C_ID_cdbd2c0db2    ...             0 -0.159749
#
# [5 rows x 6 columns]

# %%
#import holoviews as hv

plot_target = train.hvplot.hist('target')

#hv.render(plot_target)
hvplot.show(plot_target)
# Out:
#   <div class="bk-root" id="0ecb5b68-938f-4bb9-932f-441c0051a79a" data-root-id="2291"></div>

# %%
# Out:
# Line plot
#
# Parameters
# ----------
# x, y : string, optional
#     Field name to draw x- and y-positions from
# **kwds : optional
#     Keyword arguments to pass on to
#     :py:meth:`hvplot.converter.HoloViewsConverter`.
# Returns
# -------
# HoloViews object: Object representing the requested visualization
#
#
# Generic options
# ---------------
# colorbar (default=False): boolean
#     Enables colorbar
# flip_xaxis/flip_yaxis: boolean
#     Whether to flip the axis left to right or up and down respectively
# grid (default=False): boolean
#     Whether to show a grid
# hover (default=True): boolean
#     Whether to show hover tooltips
# hover_cols (default=[]): list
#     Additional columns to add to the hover tool
# invert (default=False): boolean
#     Swaps x- and y-axis
# legend (default=True): boolean or str
#     Whether to show a legend, or a legend position
#     ('top', 'bottom', 'left', 'right')
# logx/logy (default=False): boolean
# ...

# %% [markdown]
# <a id='Merchants'></a>

# %% [markdown]
# ## 2.2 Merchants

# %% [markdown]
# <a id='Historical_Transactions'></a>

# %% [markdown]
# ## 2.3 Historical Transactions

# %% [markdown]
# <a id='New_Merchant_Transactions'></a>

# %% [markdown]
# ## 2.4 New Merchant Transactions

# %%
# !pip install hvplot

# %%
import pandas as pd
import hvplot.pandas

# %%
merchant = pd.read_csv('../input/merchants.csv')

# %%
merchant.head()

# %%
# most_recent_sales_range와 most_recent_purchase_range가 일치하면 1, 불일치하면 0

merchant['coincidence'] = [1 if x == y else 0 for x,y in zip(merchant['most_recent_sales_range'], merchant['most_recent_purchases_range'])]

# %%
# merchant 전체 row에서 유니크한 row를 뺀 수

len(merchant) - merchant['merchant_id'].nunique()

# %% [markdown]
# merchant 테이블의 PK는 `merchant_id`인데 이상하게 이 변수가 유니크하지 않다. 왜 이런 이슈가 발생하는지 확인해보고자 한다.

# %%
merchant['merchant_id'].duplicated(keep=False).sum()

# %%
merchant_id_count = pd.DataFrame(merchant['merchant_id'].value_counts()).rename(columns={'merchant_id':'merchant_id_count'})
not_one_merchant = merchant_id_count[merchant_id_count['merchant_id_count'] > 1]
not_one_merchant.head()

# %%
len(not_one_merchant)

# %%
not_unique_rows = merchant[merchant['merchant_id'].isin(list(not_one_merchant.index))]
not_unique_rows.head()

# %%
not_unique_rows

# %%
cate_count.hvplot.hist()

# %%
# subsector_id와 merchant_category_id가 계층구조를 가지고 있는지 확인.
grouped_sub_id = merchant.groupby('subsector_id').agg({'merchant_category_id':'unique'}) # 각 subsector_id별 유니크한 merchant_category_id를 리스트 형태로 각 셀?에 저장
unique_merchant = [category for categories in grouped_sub_id['merchant_category_id'] for category in categories] # 각 셀?에 저장된 merchant_category_id를 꺼내서 하나의 리스트에 저장
len(unique_merchant)
